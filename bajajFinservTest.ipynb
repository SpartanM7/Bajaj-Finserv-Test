# %%
import json
import pandas as pd

with open('DataEngineeringQ2.json', 'r') as file:
    data = json.load(file)

from pandas import json_normalize

# Flatten consultationData.medicines and other nested parts for deeper analysis
flattened_data = json_normalize(data)

df = pd.DataFrame(flattened_data)

df
# Out:
#          _id appointmentId     phoneNumber      patientDetails._id  \
# 0   T6hf3rb5     40d2-9c9f     96686896670               T6hb630b3
# 1   T65g3rb5      40dbtc9f      9496368916               T6h33b300
# 2   T7g6Srb5      g3Wt5c9f      7787204833                TjhB4373
# 3   94bg8W8d      fb6-a535      9376756879                 6df4R5b
# 4   T6h8H56c       67h7KL9      5267384241                lK9hy06a
# 5    T9Jh8c8        Hy7Y91   +919826374025                 kI9d5c6
# 6   9Is624b9     10dY8a-4a      7587265252                i9R324b7
# 7   T8H9c3c6      e8056Ye8      5586958767  T6h41b5ad3d8002ad9c3c4
# 8    T8Ud380     dbc0-c66b      9987602525                T9Iy347e
# 9    T345fG4        1576a7      9234354366                 T4Rb1a2
# 10  T4F6a175       b6Te4ac      4863281056                Tr4T2173
# 11   TW3r002        bu5Qfb      8687986800                  T6Wa50
# 12   6U6Ra36       86U8Y45                                 65sRa36
# ...

# %%
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)
df = df.infer_objects()
df
# Out:
# C:\Users\maaza\AppData\Local\Temp\ipykernel_28312\3655634699.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(r'^\s*$', np.nan, regex=True, inplace=True)
#          _id appointmentId     phoneNumber      patientDetails._id  \
# 0   T6hf3rb5     40d2-9c9f     96686896670               T6hb630b3
# 1   T65g3rb5      40dbtc9f      9496368916               T6h33b300
# 2   T7g6Srb5      g3Wt5c9f      7787204833                TjhB4373
# 3   94bg8W8d      fb6-a535      9376756879                 6df4R5b
# 4   T6h8H56c       67h7KL9      5267384241                lK9hy06a
# 5    T9Jh8c8        Hy7Y91   +919826374025                 kI9d5c6
# 6   9Is624b9     10dY8a-4a      7587265252                i9R324b7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 43 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   _id                                             31 non-null     object
#  1   appointmentId                                   31 non-null     object
#  2   phoneNumber                                     26 non-null     object
#  3   patientDetails._id                              31 non-null     object
#  4   patientDetails.firstName                        31 non-null     object
#  5   patientDetails.lastName                         9 non-null      object
#  6   patientDetails.emailId                          0 non-null      float64
#  7   patientDetails.gender                           21 non-null     object
#  8   patientDetails.alternateContact                 1 non-null      object
# ...

# %%
patient_details = [entry['patientDetails'] for entry in data]


total_count = len(patient_details)
missing_first_name = 0
missing_last_name = 0
missing_dob = 0


for patient in patient_details:
    if not patient.get('firstName'):
        missing_first_name += 1
    if not patient.get('lastName'):
        missing_last_name += 1
    if not patient.get('birthDate'):
        missing_dob += 1


missing_first_name_pct = round((missing_first_name / total_count) * 100, 2)
missing_last_name_pct = round((missing_last_name / total_count) * 100, 2)
missing_dob_pct = round((missing_dob / total_count) * 100, 2)

missing_first_name_pct, missing_last_name_pct, missing_dob_pct
# Out:
# (0.0, 70.97, 32.26)

# %%
from collections import Counter

genders = [patient.get('gender') for patient in patient_details]

gender_counts = Counter(filter(None, genders))  

mode_gender = gender_counts.most_common(1)[0][0]

imputed_genders = [gender if gender else mode_gender for gender in genders]

total_count = len(imputed_genders)
female_count = imputed_genders.count('F')

female_percentage = round((female_count / total_count) * 100, 2)

female_percentage
# Out:
# 32.26

# %%
from datetime import datetime


def categorize_age(birth_date_str):
    if not birth_date_str:
        return None
    birth_date = datetime.fromisoformat(birth_date_str.replace("Z", ""))
    age = (datetime.now() - birth_date).days // 365
    if age <= 12:
        return 'Child'
    elif 13 <= age <= 19:
        return 'Teen'
    elif 20 <= age <= 59:
        return 'Adult'
    else:
        return 'Senior'

age_groups = [categorize_age(patient.get('birthDate')) for patient in patient_details]

adult_count = age_groups.count('Adult')

total_medicines = sum(len(entry['consultationData'].get('medicines', [])) for entry in data)
average_medicines = round(total_medicines / len(data), 2)

adult_count, average_medicines
# Out:
# (21, 2.13)

# %%
medicine_names = []
for record in data:
    medicines = record.get("consultationData", {}).get("medicines", [])
    for medicine in medicines:
        medicine_name = medicine.get("medicineName")
        if medicine_name:
            medicine_names.append(medicine_name)

medicine_counter = Counter(medicine_names)


most_common_medicines = medicine_counter.most_common()

if len(most_common_medicines) >= 3:
    third_most_frequent = most_common_medicines[2]  
    print(third_most_frequent[0])
else:
    print("There are fewer than 3 medicines.")
# Out:
# C

# %%
active_count = 0
inactive_count = 0


for record in data:
    medicines = record.get("consultationData", {}).get("medicines", [])
    for medicine in medicines:
        if medicine.get("isActive", False): 
            active_count += 1
        else:
            inactive_count += 1


total_medicines = active_count + inactive_count


active_percentage = (active_count / total_medicines) * 100
inactive_percentage = (inactive_count / total_medicines) * 100


print(f"Active Medicines: {active_percentage:.2f}%")
print(f"Inactive Medicines: {inactive_percentage:.2f}%")
# Out:
# Active Medicines: 69.70%
# Inactive Medicines: 30.30%

# %%
phone_numbers = []
for record in data:
    phone_numbers.append(record.get("phoneNumber", ""))

df = pd.DataFrame({'phoneNumber': phone_numbers})


def is_valid_mobile(number):
    if number.startswith('+91'):
        number = number[3:]  
    elif number.startswith('91'):
        number = number[2:] 

    
    if len(number) == 10 and number.isdigit():
        if 6000000000 <= int(number) <= 9999999999:
            return True
    return False


df['isValidMobile'] = df['phoneNumber'].apply(is_valid_mobile)


valid_count = df['isValidMobile'].sum()


print(valid_count)
# Out:
# 18

# %%
records = []
for record in data:
    patient = record.get("patientDetails", {})
    medicines = record.get("consultationData", {}).get("medicines", [])
    records.append({
        "birthDate": patient.get("birthDate"),
        "medicineCount": len(medicines),
    })

df = pd.DataFrame(records)


current_year = datetime.now().year
df['birthDate'] = pd.to_datetime(df['birthDate'], errors='coerce')
df['age'] = current_year - df['birthDate'].dt.year


correlation = df[['medicineCount', 'age']].corr(method='pearson').iloc[0, 1]


round(correlation, 2)
# Out:
# -0.21
